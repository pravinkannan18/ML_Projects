# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris=pd.read_csv('/content/Iris_Dataset.csv')

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder=LabelEncoder()

label=label_encoder.fit_transform(iris.Species)

# %%
iris['Species']=label

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    int64
# dtypes: float64(4), int64(2)
# memory usage: 7.2 KB

# %%
x=iris[['Id','SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
y=iris['Species']

# %%
x
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Species, Length: 150, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 126  127            6.2           2.8            4.8           1.8
# 23    24            5.1           3.3            1.7           0.5
# 64    65            5.6           2.9            3.6           1.3
# 117  118            7.7           3.8            6.7           2.2
# 84    85            5.4           3.0            4.5           1.5
# ..   ...            ...           ...            ...           ...
# 75    76            6.6           3.0            4.4           1.4
# 43    44            5.0           3.5            1.6           0.6
# 22    23            4.6           3.6            1.0           0.2
# 72    73            6.3           2.5            4.9           1.5
# 15    16            5.7           4.4            1.5           0.4
#
# [120 rows x 5 columns]

# %%
y_train
# Out:
# 126    2
# 23     0
# 64     1
# 117    2
# 84     1
#       ..
# 75     1
# 43     0
# 22     0
# 72     1
# 15     0
# Name: Species, Length: 120, dtype: int64

# %% [markdown]
# Model 1:Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([0, 0, 2, 0, 0, 2, 0, 2, 2, 0, 0, 0, 0, 0, 1, 1, 0, 1, 2, 1, 1, 1,
#        2, 1, 1, 0, 0, 2, 0, 2])

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %% [markdown]
# Model 2: SVM

# %%
from sklearn.svm import SVC

model=SVC()

# %%
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
model.predict(x_test)
# Out:
# array([0, 0, 2, 0, 0, 2, 0, 2, 2, 0, 1, 0, 0, 0, 1, 1, 0, 1, 2, 1, 1, 1,
#        2, 1, 1, 0, 0, 2, 0, 2])

# %%
model.score(x_test,y_test)
# Out:
# 0.9666666666666667

# %% [markdown]
# Model 3: Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
model_DTC = DecisionTreeClassifier()
model_DTC.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
prediction3= model_DTC.predict(x_test)

#calculate the accuracy
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, prediction3))
# Out:
# 1.0

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.datasets import load_iris

# Load Iris dataset
iris = load_iris()
X, y = iris.data, iris.target

# Normalize features
scaler = StandardScaler()
X_normalized = scaler.fit_transform(X)

# One-hot encode the target labels
encoder = OneHotEncoder(sparse=False)
y_onehot = encoder.fit_transform(y.reshape(-1, 1))

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_normalized, y_onehot, test_size=0.2, random_state=42)

# Build a simple neural network model
model = Sequential([
    Dense(10, activation='relu', input_shape=(4,)),
    Dense(10, activation='relu'),
    Dense(3, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=8, verbose=1)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# 15/15 [==============================] - 1s 2ms/step - loss: 1.0507 - accuracy: 0.4250
# Epoch 2/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.9540 - accuracy: 0.5083
# Epoch 3/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.8659 - accuracy: 0.6167
# Epoch 4/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7914 - accuracy: 0.7000
# Epoch 5/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.7268 - accuracy: 0.7750
# Epoch 6/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6708 - accuracy: 0.8083
# Epoch 7/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6200 - accuracy: 0.8167
# Epoch 8/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5766 - accuracy: 0.8167
# Epoch 9/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5376 - accuracy: 0.8167
# Epoch 10/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5024 - accuracy: 0.8167
# Epoch 11/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4693 - accuracy: 0.8250
# Epoch 12/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4398 - accuracy: 0.8333
# Epoch 13/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4148 - accuracy: 0.8250
# Epoch 14/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3936 - accuracy: 0.8333
# Epoch 15/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3751 - accuracy: 0.8250
# Epoch 16/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3583 - accuracy: 0.8250
# Epoch 17/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3446 - accuracy: 0.8417
# Epoch 18/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3304 - accuracy: 0.8417
# Epoch 19/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3190 - accuracy: 0.8500
# Epoch 20/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3074 - accuracy: 0.8750
# Epoch 21/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2975 - accuracy: 0.8917
# Epoch 22/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2891 - accuracy: 0.9000
# Epoch 23/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2815 - accuracy: 0.9000
# Epoch 24/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2717 - accuracy: 0.9000
# Epoch 25/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2639 - accuracy: 0.9167
# Epoch 26/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2574 - accuracy: 0.9167
# Epoch 27/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2505 - accuracy: 0.9167
# Epoch 28/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2453 - accuracy: 0.9167
# Epoch 29/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2367 - accuracy: 0.9167
# Epoch 30/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2317 - accuracy: 0.9167
# Epoch 31/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2258 - accuracy: 0.9250
# Epoch 32/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2203 - accuracy: 0.9333
# Epoch 33/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2146 - accuracy: 0.9333
# Epoch 34/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2081 - accuracy: 0.9333
# Epoch 35/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2027 - accuracy: 0.9333
# Epoch 36/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1978 - accuracy: 0.9417
# Epoch 37/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1927 - accuracy: 0.9417
# Epoch 38/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1891 - accuracy: 0.9500
# Epoch 39/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1826 - accuracy: 0.9417
# Epoch 40/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1791 - accuracy: 0.9417
# Epoch 41/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1729 - accuracy: 0.9417
# Epoch 42/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1667 - accuracy: 0.9500
# Epoch 43/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1622 - accuracy: 0.9417
# Epoch 44/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1567 - accuracy: 0.9417
# Epoch 45/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1519 - accuracy: 0.9417
# Epoch 46/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1472 - accuracy: 0.9417
# Epoch 47/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1418 - accuracy: 0.9500
# Epoch 48/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1370 - accuracy: 0.9500
# Epoch 49/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1326 - accuracy: 0.9500
# Epoch 50/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1288 - accuracy: 0.9667
# 1/1 [==============================] - 0s 212ms/step - loss: 0.0943 - accuracy: 1.0000
# Accuracy: 1.0
